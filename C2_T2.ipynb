# %%
from sqlalchemy import create_engine

import pandas as pd

# %%
#pip install pymysql

# %%
import pymysql

# %%
connection = pymysql.connect(host='data-analytics-2018.cbrosir2cswx.us-east-1.rds.amazonaws.com',
user='deepAnalytics',
password='Sqltask1234!',
database='Credit',
charset='utf8mb4',
cursorclass=pymysql.cursors.DictCursor)

# %%
credit = pd.read_sql('SELECT * FROM credit', con=connection)
# Out:
# C:\Users\pagaddam\Anaconda3\envs\DataScience\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
credit.head()
# Out:
#           X1      X2          X3        X4   X5     X6     X7     X8     X9  \
# 0  LIMIT_BAL     SEX   EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4
# 1      20000  female  university         1   24      2      2     -1     -1
# 2     120000  female  university         2   26     -1      2      0      0
# 3      90000  female  university         2   34      0      0      0      0
# 4      50000  female  university         1   37      0      0      0      0
#
#      X10  ...        X15        X16        X17       X18       X19       X20  \
# 0  PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 1     -2  ...          0          0          0         0       689         0
# 2      0  ...       3272       3455       3261         0      1000      1000
# 3      0  ...      14331      14948      15549      1518      1500      1000
# 4      0  ...      28314      28959      29547      2000      2019      1200
#
# ...

# %%
import os               # File management
import pandas as pd     # Data frame manipulation
import numpy as np      # Data frame operations
import datetime as dt   # Date operations

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3670 entries, 0 to 3669
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      3670 non-null   object
#  1   X2      3670 non-null   object
#  2   X3      3670 non-null   object
#  3   X4      3670 non-null   object
#  4   X5      3670 non-null   object
#  5   X6      3670 non-null   object
#  6   X7      3670 non-null   object
#  7   X8      3670 non-null   object
#  8   X9      3670 non-null   object
#  9   X10     3670 non-null   object
#  10  X11     3670 non-null   object
#  11  X12     3670 non-null   object
#  12  X13     3670 non-null   object
#  13  X14     3670 non-null   object
#  14  X15     3670 non-null   object
#  15  X16     3670 non-null   object
#  16  X17     3670 non-null   object
#  17  X18     3670 non-null   object
#  18  X19     3670 non-null   object
#  19  X20     3670 non-null   object
#  20  X21     3670 non-null   object
# ...

# %%
import pandas_profiling

# %%
pandas_profiling.ProfileReport(credit)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.7.1&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-10-26 22:19:31.756532&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# had to adjust the boolean.py using visual studio.
# file path is  : C:\Users\pagaddam\Anaconda3\envs\DataScience\Lib\site-packages\visions\dtypes

# %%
credit['X2'].unique()
# Out:
# array(['SEX', 'female', 'male'], dtype=object)

# %%
credit[credit['X2'] == 'SEX']
# Out:
#              X1   X2         X3        X4   X5     X6     X7     X8     X9  \
# 0     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4
# 2398  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4
#
#         X10  ...        X15        X16        X17       X18       X19  \
# 0     PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2
# 2398  PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2
#
#            X20       X21       X22       X23                           Y
# 0     PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 2398  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
#
# [2 rows x 24 columns]

# %%
credit = credit.drop(index = 2398)
# observed that the header row is duplicated at row index 2398. so cleared that row by using drop command.

# %%
credit.describe()
# Out:
#            X1      X2          X3    X4    X5    X6    X7    X8    X9   X10  \
# count    3669    3669        3669  3669  3669  3669  3669  3669  3669  3669
# unique     63       3           5     5    53    10    11    11    10     9
# top     50000  female  university     2    29     0     0     0     0     0
# freq      453    2130        1644  2045   214  1741  1901  1875  1995  1996
#
#         ...   X15   X16   X17   X18   X19   X20   X21   X22   X23            Y
# count   ...  3669  3669  3669  3669  3669  3669  3669  3669  3669         3669
# unique  ...  2009  1984  1948  1147  1130  1041  1035  1039   971            3
# top     ...     0     0     0     0     0     0     0     0     0  not default
# freq    ...   424   460   532   667   708   798   808   827   949         2873
#
# [4 rows x 24 columns]

# %%
credit.columns = credit.iloc[0]
credit = credit.reindex(credit.index.drop(0)).reset_index(drop=True)
credit.columns.name = None
credit.head(5)
# Out:
#   LIMIT_BAL     SEX   EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4 PAY_5  \
# 0     20000  female  university        1  24     2     2    -1    -1    -2
# 1    120000  female  university        2  26    -1     2     0     0     0
# 2     90000  female  university        2  34     0     0     0     0     0
# 3     50000  female  university        1  37     0     0     0     0     0
# 4     50000    male  university        1  57    -1     0    -1     0     0
#
#    ... BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3 PAY_AMT4  \
# 0  ...         0         0         0        0      689        0        0
# 1  ...      3272      3455      3261        0     1000     1000     1000
# 2  ...     14331     14948     15549     1518     1500     1000     1000
# 3  ...     28314     28959     29547     2000     2019     1200     1100
# 4  ...     20940     19146     19131     2000    36681    10000     9000
#
#   PAY_AMT5 PAY_AMT6 default payment next month
# ...

# %%
credit.describe()
# Out:
#        LIMIT_BAL     SEX   EDUCATION MARRIAGE   AGE PAY_0 PAY_2 PAY_3 PAY_4  \
# count       3668    3668        3668     3668  3668  3668  3668  3668  3668
# unique        62       2           4        4    52     9    10    10     9
# top        50000  female  university        2    29     0     0     0     0
# freq         453    2130        1644     2045   214  1741  1901  1875  1995
#
#        PAY_5  ... BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3  \
# count   3668  ...      3668      3668      3668     3668     3668     3668
# unique     8  ...      2008      1983      1947     1146     1129     1040
# top        0  ...         0         0         0        0        0        0
# freq    1996  ...       424       460       532      667      708      798
#
#        PAY_AMT4 PAY_AMT5 PAY_AMT6 default payment next month
# count      3668     3668     3668                       3668
# unique     1034     1038      970                          2
# ...

# %%
credit = credit.drop_duplicates()

# %%
credit['EDUCATION'].unique()
# Out:
# array(['university', 'graduate school', 'high school', 'other'],
#       dtype=object)

# %%
credit['MARRIAGE'].unique()
# Out:
# array(['1', '2', '3', '0'], dtype=object)

# %%
credit
# Out:
#      LIMIT_BAL     SEX    EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4  \
# 0        20000  female   university        1  24     2     2    -1    -1
# 1       120000  female   university        2  26    -1     2     0     0
# 2        90000  female   university        2  34     0     0     0     0
# 3        50000  female   university        1  37     0     0     0     0
# 4        50000    male   university        1  57    -1     0    -1     0
# ...        ...     ...          ...      ...  ..   ...   ...   ...   ...
# 2392     50000    male  high school        1  32     2     3     2     2
# 2393     20000  female  high school        2  49     0     0     2     0
# 2394    130000  female   university        2  24     1    -2    -1    -1
# 2395    110000  female  high school        1  27     0     0     0     0
# 2396    200000    male   university        1  29     0     0     0     2
#
#      PAY_5  ... BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3  \
# ...

# %%
credit.to_csv("downloadfromSQL.csv")

# %%
credit1 = credit[['LIMIT_BAL','SEX','EDUCATION','MARRIAGE','AGE', 'default payment next month']]

# %%
credit1
# Out:
#      LIMIT_BAL     SEX    EDUCATION MARRIAGE AGE default payment next month
# 0        20000  female   university        1  24                    default
# 1       120000  female   university        2  26                    default
# 2        90000  female   university        2  34                not default
# 3        50000  female   university        1  37                not default
# 4        50000    male   university        1  57                not default
# ...        ...     ...          ...      ...  ..                        ...
# 2392     50000    male  high school        1  32                    default
# 2393     20000  female  high school        2  49                not default
# 2394    130000  female   university        2  24                not default
# 2395    110000  female  high school        1  27                not default
# 2396    200000    male   university        1  29                not default
#
# [2396 rows x 6 columns]

# %%
# library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# to find any NA values in the data set.
credit.isna().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
# to find any NULL values in the data set.
credit.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
credit.dtypes
# Out:
# LIMIT_BAL                     object
# SEX                           object
# EDUCATION                     object
# MARRIAGE                      object
# AGE                           object
# PAY_0                         object
# PAY_2                         object
# PAY_3                         object
# PAY_4                         object
# PAY_5                         object
# PAY_6                         object
# BILL_AMT1                     object
# BILL_AMT2                     object
# BILL_AMT3                     object
# BILL_AMT4                     object
# BILL_AMT5                     object
# BILL_AMT6                     object
# PAY_AMT1                      object
# PAY_AMT2                      object
# PAY_AMT3                      object
# PAY_AMT4                      object
# PAY_AMT5                      object
# PAY_AMT6                      object
# default payment next month    object
# dtype: object

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn import linear_model

# %%
#conda install -c conda-forge pandas-profiling

# %%
import pandas_profiling

# %%
#pandas_profiling.ProfileReport(credit)

# %%
credit.columns= ['Limit_Bal', 'Sex', 'Education', 'Marriage', 'Age', 'Status_Sept', 'Status_Aug', 'Status_Jul', 'Status_Jun', 'Status_May', 'Status_Apr', 'Bill_Sept', 'Bill_Aug', 'Bill_Jul', 'Bill_Jun', 'Bill_May', 'Bill_Apr', 'Pay_Sept', 'Pay_Aug', 'Pay_Jul', 'Pay_Jun', 'Pay_May', 'Pay_Apr', 'Default_Status']

# %%
credit = credit.astype({'Limit_Bal': np.int64, 
                        'Marriage': np.int64, 
                        'Age': np.int64, 
                        'Status_Sept': np.int64, 
                        'Status_Aug': np.int64, 
                        'Status_Jul': np.int64, 
                        'Status_Jun': np.int64, 
                        'Status_May': np.int64, 
                        'Status_Apr': np.int64, 
                        'Bill_Sept': np.int64, 
                        'Bill_Aug': np.int64, 
                        'Bill_Jul': np.int64, 
                        'Bill_Jun': np.int64, 
                        'Bill_May': np.int64, 
                        'Bill_Apr': np.int64, 
                        'Pay_Sept': np.int64, 
                        'Pay_Aug': np.int64, 
                        'Pay_Jul': np.int64,
                        'Pay_Jun': np.int64, 
                        'Pay_May': np.int64, 
                        'Pay_Apr': np.int64, })

# %%
credit.dtypes
# Out:
# Limit_Bal          int64
# Sex               object
# Education         object
# Marriage           int64
# Age                int64
# Status_Sept        int64
# Status_Aug         int64
# Status_Jul         int64
# Status_Jun         int64
# Status_May         int64
# Status_Apr         int64
# Bill_Sept          int64
# Bill_Aug           int64
# Bill_Jul           int64
# Bill_Jun           int64
# Bill_May           int64
# Bill_Apr           int64
# Pay_Sept           int64
# Pay_Aug            int64
# Pay_Jul            int64
# Pay_Jun            int64
# Pay_May            int64
# Pay_Apr            int64
# Default_Status    object
# dtype: object

# %%
credit = pd.get_dummies(credit, columns=['Sex', 'Education'])

# %%
credit = pd.get_dummies(credit, columns=['Default_Status'])

# %%
credit.dtypes
# Out:
# Limit_Bal                     int64
# Marriage                      int64
# Age                           int64
# Status_Sept                   int64
# Status_Aug                    int64
# Status_Jul                    int64
# Status_Jun                    int64
# Status_May                    int64
# Status_Apr                    int64
# Bill_Sept                     int64
# Bill_Aug                      int64
# Bill_Jul                      int64
# Bill_Jun                      int64
# Bill_May                      int64
# Bill_Apr                      int64
# Pay_Sept                      int64
# Pay_Aug                       int64
# Pay_Jul                       int64
# Pay_Jun                       int64
# Pay_May                       int64
# Pay_Apr                       int64
# Sex_female                    uint8
# Sex_male                      uint8
# Education_graduate school     uint8
# Education_high school         uint8
# Education_other               uint8
# ...

# %%
credit.head()
# Out:
#    Limit_Bal  Marriage  Age  Status_Sept  Status_Aug  Status_Jul  Status_Jun  \
# 0      20000         1   24            2           2          -1          -1
# 1     120000         2   26           -1           2           0           0
# 2      90000         2   34            0           0           0           0
# 3      50000         1   37            0           0           0           0
# 4      50000         1   57           -1           0          -1           0
#
#    Status_May  Status_Apr  Bill_Sept  ...  Pay_May  Pay_Apr  Sex_female  \
# 0          -2          -2       3913  ...        0        0           1
# 1           0           2       2682  ...        0     2000           1
# 2           0           0      29239  ...     1000     5000           1
# 3           0           0      46990  ...     1069     1000           1
# 4           0           0       8617  ...      689      679           0
#
#    Sex_male  Education_graduate school  Education_high school  \
# ...

# %%
credit['Age'].hist()
# Out:
# <AxesSubplot:>

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['Limit_Bal', 'Marriage', 'Age', 'Status_Sept', 'Status_Aug',
#        'Status_Jul', 'Status_Jun', 'Status_May', 'Status_Apr', 'Bill_Sept',
#        'Bill_Aug', 'Bill_Jul', 'Bill_Jun', 'Bill_May', 'Bill_Apr', 'Pay_Sept',
#        'Pay_Aug', 'Pay_Jul', 'Pay_Jun', 'Pay_May', 'Pay_Apr', 'Sex_female',
#        'Sex_male', 'Education_graduate school', 'Education_high school',
#        'Education_other', 'Education_university', 'Default_Status_default',
#        'Default_Status_not default'],
#       dtype='object')

# %%
plt.hist(credit['Limit_Bal'],bins=4)
plt.show()

# %%
# how many ever bins i keep the histtogram doesnot change accordingly.

# %%
pd.cut(credit['Limit_Bal'], bins=4)
# Out:
# 0       (9010.0, 257500.0]
# 1       (9010.0, 257500.0]
# 2       (9010.0, 257500.0]
# 3       (9010.0, 257500.0]
# 4       (9010.0, 257500.0]
#                ...
# 2392    (9010.0, 257500.0]
# 2393    (9010.0, 257500.0]
# 2394    (9010.0, 257500.0]
# 2395    (9010.0, 257500.0]
# 2396    (9010.0, 257500.0]
# Name: Limit_Bal, Length: 2396, dtype: category
# Categories (4, interval[float64, right]): [(9010.0, 257500.0] < (257500.0, 505000.0] < (505000.0, 752500.0] < (752500.0, 1000000.0]]

# %%
pd.cut(credit['Limit_Bal'], bins=4).value_counts()
# Out:
# (9010.0, 257500.0]       1882
# (257500.0, 505000.0]      494
# (505000.0, 752500.0]       19
# (752500.0, 1000000.0]       1
# Name: Limit_Bal, dtype: int64

# %%
credit[credit['Limit_Bal'] > 752500.0]
# Out:
#       Limit_Bal  Marriage  Age  Status_Sept  Status_Aug  Status_Jul  \
# 2197    1000000         1   47            0           0           0
#
#       Status_Jun  Status_May  Status_Apr  Bill_Sept  ...  Pay_May  Pay_Apr  \
# 2197          -1           0           0     964511  ...    50000    50256
#
#       Sex_female  Sex_male  Education_graduate school  Education_high school  \
# 2197           1         0                          1                      0
#
#       Education_other  Education_university  Default_Status_default  \
# 2197                0                     0                       0
#
#       Default_Status_not default
# 2197                           1
#
# [1 rows x 29 columns]

# %%
credit = credit.drop(index = 2197)

# %%
# after removing the outlier
pd.cut(credit['Limit_Bal'], bins=4).value_counts()
# Out:
# (9310.0, 182500.0]      1498
# (182500.0, 355000.0]     635
# (355000.0, 527500.0]     245
# (527500.0, 700000.0]      17
# Name: Limit_Bal, dtype: int64

# %%
cut_labels = ['10,000', '50,000', '140,000', '230,000', '1.000,000']
cut_bins = [0, 10000, 50000, 140000, 230000, 1000000]
credit['Limit_Bins'] = pd.cut(credit['Limit_Bal'], bins=cut_bins, labels=cut_labels)

# %%
credit['Limit_Bins'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 2395 entries, 0 to 2396
# Series name: Limit_Bins
# Non-Null Count  Dtype
# --------------  -----
# 2395 non-null   category
# dtypes: category(1)
# memory usage: 21.3 KB

# %%
credit.head(15)
# Out:
#     Limit_Bal  Marriage  Age  Status_Sept  Status_Aug  Status_Jul  Status_Jun  \
# 0       20000         1   24            2           2          -1          -1
# 1      120000         2   26           -1           2           0           0
# 2       90000         2   34            0           0           0           0
# 3       50000         1   37            0           0           0           0
# 4       50000         1   57           -1           0          -1           0
# 5       50000         2   37            0           0           0           0
# 6      500000         2   29            0           0           0           0
# 7      100000         2   23            0          -1          -1           0
# 8      140000         1   28            0           0           2           0
# 9       20000         2   35           -2          -2          -2          -2
# 10     200000         2   34            0           0           2           0
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
credit['Limit_Bins'].hist()
plt.show()

# %%
credit.groupby('Sex_female')['Sex_female'].count()
# Out:
# Sex_female
# 0    1012
# 1    1383
# Name: Sex_female, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(3, 5)) 
x= ['Male', 'Female']
y= [1012, 1384]
bar_labels = ['Male', 'Female']
bar_colors = ['black', 'orange']

ax.bar(x, y, label=bar_labels, color=bar_colors)

ax.set_ylabel('Count')
ax.set_title('Gender')

plt.show()

# %%
credit.groupby('Default_Status_default')['Default_Status_default'].count()
# Out:
# Default_Status_default
# 0    1876
# 1     519
# Name: Default_Status_default, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(3, 5)) 
x= ['Did not Default', 'Defaulted']
y= [1877, 519]
bar_labels = ['Did not Default', 'Defaulted']
bar_colors = ['Green', 'Red']

ax.bar(x, y, label=bar_labels, color=bar_colors)

ax.set_ylabel('Count')
ax.set_title('Default Status')

plt.show()

# %%
credit.groupby(['Sex_female', 'Default_Status_default'])['Sex_female'].count()
# Out:
# Sex_female  Default_Status_default
# 0           0                          790
#             1                          222
# 1           0                         1086
#             1                          297
# Name: Sex_female, dtype: int64

# %%
labels = ['Male', 'Female']

did_not_default = [790, 1086]
defaulted = [222, 297]

x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots(figsize=(8, 6)) 
rects1 = ax.bar(x - width/2, did_not_default, width, color='Green', label='Did not Default')
rects2 = ax.bar(x + width/2, defaulted, width, color='Red', label='Defaulted')

ax.set_ylabel('Count')
ax.set_title('Default Status by Gender', fontsize=15 )
ax.set_xticks(x, labels)
ax.legend(fontsize=15)

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %%
credit.groupby(['Sex_female', 'Limit_Bins'])['Sex_female'].count()
# Out:
# Sex_female  Limit_Bins
# 0           10,000         25
#             50,000        298
#             140,000       221
#             230,000       208
#             1.000,000     260
# 1           10,000         12
#             50,000        299
#             140,000       388
#             230,000       358
#             1.000,000     326
# Name: Sex_female, dtype: int64

# %%
credit.groupby(['Marriage', 'Default_Status_default'])['Marriage'].count()
# Out:
# Marriage  Default_Status_default
# 0         0                            6
# 1         0                          787
#           1                          239
# 2         0                         1058
#           1                          272
# 3         0                           25
#           1                            8
# Name: Marriage, dtype: int64

# %%
labels = ['Married', 'Single', 'Divorced', 'Other']

did_not_default = [787, 1058, 25, 6]
defaulted = [239, 272, 8, 0]

x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots(figsize=(8, 6)) 
rects1 = ax.bar(x - width/2, did_not_default, width, color='Green', label='Did not Default')
rects2 = ax.bar(x + width/2, defaulted, width, color='Red', label='Defaulted')

ax.set_ylabel('Count')
ax.set_title('Default Status by Marital Status', fontsize=15 )
ax.set_xticks(x, labels)
ax.legend(fontsize=15)

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %%
High_School = credit[credit['Education_high school']==1]
University = credit[credit['Education_university']==1]
Graduate_School = credit[credit['Education_graduate school']==1]
Other = credit[credit['Education_other']==1]

# %%
High_School.groupby('Default_Status_default')['Default_Status_default'].count()
# Out:
# Default_Status_default
# 0    291
# 1    101
# Name: Default_Status_default, dtype: int64

# %%
University.groupby('Default_Status_default')['Default_Status_default'].count()
# Out:
# Default_Status_default
# 0    836
# 1    241
# Name: Default_Status_default, dtype: int64

# %%
Graduate_School.groupby('Default_Status_default')['Default_Status_default'].count()
# Out:
# Default_Status_default
# 0    732
# 1    176
# Name: Default_Status_default, dtype: int64

# %%
Other.groupby('Default_Status_default')['Default_Status_default'].count()
# Out:
# Default_Status_default
# 0    17
# 1     1
# Name: Default_Status_default, dtype: int64

# %%
labels = ['High School', 'University', 'Graduate School', 'Other']

did_not_default = [291, 836, 732, 17]
defaulted = [101, 241, 176, 1]

x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots(figsize=(8, 6)) 
rects1 = ax.bar(x - width/2, did_not_default, width, color='Green', label='Did not Default')
rects2 = ax.bar(x + width/2, defaulted, width, color='Red', label='Defaulted')

ax.set_ylabel('Count')
ax.set_title('Default Status by Education', fontsize=15 )
ax.set_xticks(x, labels)
ax.legend(fontsize=15)

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %%
import seaborn as sns 
# %matplotlib inline

# %%
age = credit['Age']

# %%
age_dist = sns.distplot(age)
age_dist.set_title("Distribution of Customer Ages")
# Out:
# C:\Users\pagaddam\Anaconda3\envs\DataScience\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of Customer Ages')

# %%
credit_sample=credit.sample(500)

# %%
x = credit_sample['Age']
y = credit_sample['Limit_Bal']

plt.scatter(x,y, marker='.')
plt.show()

# %%
plt.plot(credit['Limit_Bal'])
plt.show()

# %%
x = credit_sample['Pay_Sept']
y = credit_sample['Pay_Aug']

plt.scatter(x,y)
plt.show()

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['Limit_Bal', 'Marriage', 'Age', 'Status_Sept', 'Status_Aug',
#        'Status_Jul', 'Status_Jun', 'Status_May', 'Status_Apr', 'Bill_Sept',
#        'Bill_Aug', 'Bill_Jul', 'Bill_Jun', 'Bill_May', 'Bill_Apr', 'Pay_Sept',
#        'Pay_Aug', 'Pay_Jul', 'Pay_Jun', 'Pay_May', 'Pay_Apr', 'Sex_female',
#        'Sex_male', 'Education_graduate school', 'Education_high school',
#        'Education_other', 'Education_university', 'Default_Status_default',
#        'Default_Status_not default', 'Limit_Bins'],
#       dtype='object')

# %%
A = credit['Limit_Bal']
plt.boxplot(A,0,'gD',vert=False)
plt.show()

# %%
Age = credit['Age']
plt.boxplot(Age,0,'gD',vert=False)
plt.show()

# %%
defaulted = credit[credit['Default_Status_default']==1]

# %%
defaulted.describe()
# Out:
#            Limit_Bal    Marriage         Age  Status_Sept  Status_Aug  \
# count     519.000000  519.000000  519.000000   519.000000  519.000000
# mean   145067.437380    1.554913   36.132948     0.620424    0.327553
# std    121343.609247    0.527588   10.147543     1.303562    1.505662
# min     10000.000000    1.000000   21.000000    -2.000000   -2.000000
# 25%     50000.000000    1.000000   28.000000     0.000000   -1.000000
# 50%    110000.000000    2.000000   35.000000     1.000000    0.000000
# 75%    210000.000000    2.000000   42.000000     2.000000    2.000000
# max    620000.000000    3.000000   73.000000     8.000000    7.000000
#
#        Status_Jul  Status_Jun  Status_May  Status_Apr      Bill_Sept  ...  \
# count  519.000000  519.000000  519.000000  519.000000     519.000000  ...
# mean     0.337187    0.136802    0.152216    0.042389   51285.431599  ...
# std      1.611968    1.535479    1.540305    1.537854   79463.623001  ...
# ...

# %%
age_d = defaulted['Age']

# %%
age_d_dist = sns.distplot(age_d)
age_d_dist.set_title("Distribution of Defaulted Customer Ages")
# Out:
# C:\Users\pagaddam\Anaconda3\envs\DataScience\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of Defaulted Customer Ages')

# %%
credit.corr()
# Out:
#                             Limit_Bal  Marriage       Age  Status_Sept  \
# Limit_Bal                    1.000000 -0.146126  0.153057    -0.202289
# Marriage                    -0.146126  1.000000 -0.419944     0.025898
# Age                          0.153057 -0.419944  1.000000    -0.017839
# Status_Sept                 -0.202289  0.025898 -0.017839     1.000000
# Status_Aug                  -0.250720  0.037354 -0.029971     0.637670
# Status_Jul                  -0.238600  0.039021 -0.037864     0.547807
# Status_Jun                  -0.224597  0.046548 -0.024254     0.497550
# Status_May                  -0.215928  0.044648 -0.012753     0.472582
# Status_Apr                  -0.213384  0.041238 -0.009588     0.445631
# Bill_Sept                    0.343170 -0.036104  0.064151     0.176813
# Bill_Aug                     0.342039 -0.033033  0.057132     0.181142
# Bill_Jul                     0.353508 -0.044543  0.063007     0.175290
# ...

# %%
credit.shape
# Out:
# (2395, 30)

# %%
import seaborn as sn
creditCorr = credit.corr()
filteredcredit = creditCorr[((creditCorr >= .5) | (creditCorr <= -.5)) & (creditCorr !=1.000)]
plt.figure(figsize=(30,10))
sn.heatmap(filteredcredit, annot=True, cmap="Reds")
plt.show()

# %%
def corrFilter(x: pd.DataFrame, bound: float):
    xCorr = x.corr()
    xFiltered = xCorr[((xCorr >= bound) | (xCorr <= -bound)) & (xCorr !=1.000) & (xCorr != -1.00000)]
    xFlattened = xFiltered.unstack().sort_values().drop_duplicates()
    return xFlattened

corrFilter(credit, .8)
# Out:
# Default_Status_not default  Default_Status_default   -1.000000
# Status_Jul                  Status_Jun                0.812556
# Status_May                  Status_Apr                0.815937
# Bill_Sept                   Bill_Apr                  0.831439
# Status_May                  Status_Jun                0.836004
# Bill_Sept                   Bill_May                  0.848603
# Bill_Apr                    Bill_Aug                  0.862855
# Bill_Sept                   Bill_Jun                  0.871485
# Bill_Apr                    Bill_Jul                  0.883355
# Bill_May                    Bill_Aug                  0.885632
# Bill_Apr                    Bill_Jun                  0.900597
# Bill_Aug                    Bill_Jun                  0.910469
# Bill_Sept                   Bill_Jul                  0.911579
# Bill_May                    Bill_Jul                  0.913239
#                             Bill_Apr                  0.939327
# ...

# %%
## to get heat map
#corr = credit.corr()

#kot = corr[corr>=.9]
#plt.figure(figsize=(12,8))
#sns.heatmap(kot, cmap="Greens")

# %%
def covFilter(x: pd.DataFrame, bound: float):
    xCorr = x.cov()
    xFiltered = xCorr[((xCorr >= bound) | (xCorr <= -bound)) & (xCorr !=1.000) & (xCorr != -1.00000)]
    xFlattened = xFiltered.unstack().sort_values().drop_duplicates()
    return xFlattened

corrFilter(credit, .2)
# Out:
# Default_Status_not default  Default_Status_default   -1.000000
# Education_graduate school   Education_university     -0.706379
# Age                         Marriage                 -0.419944
# Education_high school       Education_university     -0.399901
# Education_graduate school   Education_high school    -0.345693
#                                                         ...
# Bill_Jul                    Bill_Jun                  0.940944
# Bill_Jun                    Bill_May                  0.941602
# Bill_Sept                   Bill_Aug                  0.951020
# Bill_Aug                    Bill_Jul                  0.953444
# Limit_Bal                   Limit_Bal                      NaN
# Length: 104, dtype: float64

# %%
credit_default = credit[credit['Default_Status_default'] == 1]

# %%
credit_default.corr()
# Out:
#                             Limit_Bal  Marriage       Age  Status_Sept  \
# Limit_Bal                    1.000000 -0.192673  0.152062    -0.141960
# Marriage                    -0.192673  1.000000 -0.400720     0.009313
# Age                          0.152062 -0.400720  1.000000     0.030530
# Status_Sept                 -0.141960  0.009313  0.030530     1.000000
# Status_Aug                  -0.294077  0.016197 -0.031664     0.574932
# Status_Jul                  -0.281546  0.056500 -0.032959     0.445051
# Status_Jun                  -0.269907  0.061009  0.013079     0.406964
# Status_May                  -0.272578  0.059774  0.035632     0.396109
# Status_Apr                  -0.273335  0.087541  0.028338     0.404795
# Bill_Sept                    0.373700 -0.100334  0.087102     0.180745
# Bill_Aug                     0.363135 -0.100582  0.089832     0.187856
# Bill_Jul                     0.365009 -0.087975  0.095472     0.189624
# ...

# %%
labels = ['Male', 'Female']

did_not_default = [790, 1086]
defaulted = [222, 297]

x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots(figsize=(8, 6)) 
rects1 = ax.bar(x - width/2, did_not_default, width, color='Green', label='Did not Default')
rects2 = ax.bar(x + width/2, defaulted, width, color='Red', label='Defaulted')

ax.set_ylabel('Count')
ax.set_title('Default Status by Gender', fontsize=15 )
ax.set_xticks(x, labels)
ax.legend(fontsize=15)

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %%
credit_default.groupby(['Sex_female', 'Default_Status_default'])['Sex_female'].count()
# Out:
# Sex_female  Default_Status_default
# 0           1                         222
# 1           1                         297
# Name: Sex_female, dtype: int64

# %%
credit_default.head()
# Out:
#     Limit_Bal  Marriage  Age  Status_Sept  Status_Aug  Status_Jul  Status_Jun  \
# 0       20000         1   24            2           2          -1          -1
# 1      120000         2   26           -1           2           0           0
# 13      70000         2   30            1           2           2           0
# 16      20000         2   24            0           0           2           2
# 21     120000         1   39           -1          -1          -1          -1
#
#     Status_May  Status_Apr  Bill_Sept  ...  Pay_Apr  Sex_female  Sex_male  \
# 0           -2          -2       3913  ...        0           1         0
# 1            0           2       2682  ...     2000           1         0
# 13           0           2      65802  ...        0           0         1
# 16           2           2      15376  ...        0           0         1
# 21          -1          -1        316  ...        0           1         0
#
# ...

# %%
# - females are defaulting more.

# %%
credit_default.groupby(['Sex_female', 'Limit_Bins'])['Sex_female'].count()
# Out:
# Sex_female  Limit_Bins
# 0           10,000         8
#             50,000        75
#             140,000       54
#             230,000       45
#             1.000,000     40
# 1           10,000         5
#             50,000        83
#             140,000       79
#             230,000       69
#             1.000,000     61
# Name: Sex_female, dtype: int64

# %%
credit_default.groupby(['Sex_female', 'Limit_Bins','Marriage'])['Sex_female'].count()
# Out:
# Sex_female  Limit_Bins  Marriage
# 0           10,000      1            2
#                         2            6
#                         3            0
#             50,000      1           26
#                         2           47
#                         3            2
#             140,000     1           24
#                         2           29
#                         3            1
#             230,000     1           26
#                         2           19
#                         3            0
#             1.000,000   1           25
#                         2           15
#                         3            0
# 1           10,000      1            1
#                         2            4
#                         3            0
#             50,000      1           33
#                         2           48
#                         3            2
#             140,000     1           31
#                         2           45
# ...

# %%
credit_default = credit[credit['Default_Status_default'] == 1]
